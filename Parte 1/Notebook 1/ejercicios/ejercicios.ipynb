# %% [markdown]
# ## Ejercicio 1
#
# En la celda de código siguiente crea un dataframe llamado frutas que tenga esta estructura:
# <br><br>
# <img src="imgs/ej-01.PNG">

# %%
import pandas as pd
frutas=pd.DataFrame({'Manzanas': [30], 'Platanos': [21]})
frutas
# Out:
#    Manzanas  Platanos
# 0        30        21

# %% [markdown]
# ## Ejercicio 2
#
# Crea un dataframe llamado ventas_frutas que encaje con la siguiente foto:
#
# <br>
#
# <img src="imgs/ej-01.2.PNG">

# %%
ventasFrutas=pd.DataFrame({'Manzanas': [35,41], 'Platanos': [21,34]}, index=['Ventas 2017','Ventas 2018'])
ventasFrutas
# Out:
#              Manzanas  Platanos
# Ventas 2017        35        21
# Ventas 2018        41        34

# %% [markdown]
# ## Ejercicio 3
#
# Crea una variable ingredientes que sea una serie con este contenido:
#
# <img src="imgs/ej-01.3.PNG">

# %%
ingredientes=pd.Series(['4 Tazas', '1 Taza','2 unidades XL','1 Pieza'], index=['Harina','Leche','Huevos','Limon'], name='Cena')
ingredientes
# Out:
# Harina          4 Tazas
# Leche            1 Taza
# Huevos    2 unidades XL
# Limon           1 Pieza
# Name: Cena, dtype: str

# %% [markdown]
# ## Ejercicio 4
#
# Lee el dataset llamado **datos_casas_india.csv** que está en la ruta **datasets/datos_casas_india.csv** en una variable de tipo dataframe y llámalo casas_india, finalmente muestra su contenido.

# %%
datos_casas_indias=pd.read_csv("datasets/datos_casas_india.csv")
datos_casas_indias.head()
datos_casas_indias.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 datos_casas_indias=pd.read_csv("datasets/datos_casas_india.csv")
#       2 datos_casas_indias.head()
#       3 datos_casas_indias.shape
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ## Ejercicio 5
#
# Ejecuta la siguiente celda para crear un dataframe llamado animales y crea una celda extra en la que se escriba ese dataframe en un fichero CSV en la ruta **datasets/animales.csv**

# %%
animales = pd.DataFrame({
    'nombre': ['perro', 'gato', 'conejo'],
    'edad': [5, 3, 2]
})

animales.to_csv('datasets/animales.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[97], line 6
#       1 animales = pd.DataFrame({
#       2     'nombre': ['perro', 'gato', 'conejo'],
#       3     'edad': [5, 3, 2]
#       4 })
# ----> 6 animales.to_csv('datasets/animales.csv')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
# ...
